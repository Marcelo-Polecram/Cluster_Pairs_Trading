# %% [markdown]
# ## Importação das bibliotecas e funções

# %%
import warnings
warnings.filterwarnings('ignore')

import math
import numpy as np
import pandas as pd
from tqdm import tqdm
from pathlib import Path
import os
import datetime
import statsmodels.api as sm
import statsmodels.tsa.stattools as ts

# %%
# Usando Google Colab:
'''
from google.colab import drive
drive.mount('/content/drive')

pasta = str("/content/drive/MyDrive/Python/TCC-Cloud/Data/")
print(pasta)

preços = pd.read_csv(pasta + "Preços.csv",index_col='Data',parse_dates=True)
semestres = pd.read_csv(pasta + "Semestres.csv",parse_dates=True)

Datas = pd.DataFrame(preços.index)
Datas['indice'] = Datas.index
log_data = np.log(preços)
'''
# Out:
# '\nfrom google.colab import drive\ndrive.mount(\'/content/drive\')\n\npasta = str("/content/drive/MyDrive/Python/TCC-Cloud/Data/")\nprint(pasta)\n\npreços = pd.read_csv(pasta + "Preços.csv",index_col=\'Data\',parse_dates=True)\nsemestres = pd.read_csv(pasta + "Semestres.csv",parse_dates=True)\n\nDatas = pd.DataFrame(preços.index)\nDatas[\'indice\'] = Datas.index\nlog_data = np.log(preços)\n'

# %%
# Especificando o caminho padrão do projeto no computador:
pasta = str(Path.cwd().parents[0])
print(pasta)

preços = pd.read_csv(pasta + "/Data/Preços.csv",index_col='Data',parse_dates=True)
semestres = pd.read_csv(pasta + "/Data/Semestres.csv",parse_dates=True)

Datas = pd.DataFrame(preços.index)
Datas['indice'] = Datas.index
log_data = np.log(preços)
# Out:
# /mnt/c/Users/MarceloPolecram/Python/MEU_TCC

# %%
# MQO para encontrar o coeficiente de cointegração e criando a serie do spread
def OLS(data_ticker1, data_ticker2):
    spread = sm.OLS(data_ticker1,data_ticker2)
    spread = spread.fit()
    return data_ticker1 + (data_ticker2 * -spread.params[0]), spread.params[0]


# ADF test
def ADF(spread):
    return ts.adfuller(spread) # H0: Raiz unitária.


# Encontra o coeficiente de cointegração e realiza o ADF test
def ADF_test(data_ticker1, data_ticker2):
    ols = OLS(data_ticker1, data_ticker2)
    spread = ols[0]
    gamma = ols[1]
    return ADF(spread),gamma


# Encontra os pares cointegrados
def find_cointegrated_pairs_mod(data):
    try:
        print(f"Finding cointegrated pairs for shape {np.shape(data)}")
        n = data.shape[1]
        pvalue_matrix = np.ones((n, n))
        gammas_matrix = np.ones((n, n))
        keys = data.keys()
        for i in range(n):
            for j in range(i+1, n):
                S1 = keys[i]
                S2 = keys[j]
                #print(f"Testing cointegration for pairs {S1} and {S2}")
                result = ADF_test(data[S1], data[S2])
                gammas_matrix[i, j] =result[1] # gamma
                pvalue = result[0][1] # pvalue
                pvalue_matrix[i, j] = pvalue
            if(i%50 == 0):
                print(f"Finished pairs for stock {keys[i]}")
        return pvalue_matrix, gammas_matrix
    except Exception as e:
        print(e)


# Ordenando os melhores pares
def top_coint_pairs(data,pvalue_matrix,gamma, alpha,semestre,n):
#alpha = nivel de significancia para o teste ADF
#n = top n ativos com o menor pvalue
    alpha_filter = np.where(pvalues < alpha)
    pvalues_f = pvalues[alpha_filter] # pvalores menores que alpha
    #print(f"Alpha filter rows len {len(alpha_filter[0])} | cols len {len(alpha_filter[1])} | value {alpha_filter}")
    #print(f"pvalues_f len: {np.shape(pvalues_f)} | value: {pvalues_f}")
    stock_a = data.columns[list(alpha_filter)[0]] # relacionando o pvalor com a ação A
    stock_b = data.columns[list(alpha_filter)[1]] # relacionando o pvalor com a ação B
    gammas_f = gammas[alpha_filter] # relacionando o pvalor com o gamma
    N = len(list(alpha_filter[0])) # quantidade de pares cointegrados

    d = []
    for i in range(N):
        pair_dict = {
            'Stock A': stock_a[i],
            'Stock B': stock_b[i],
            'P-Values': pvalues_f[i],
            'Gamma': gammas_f[i],
            'Semestre' : semestre
        }
        #if(i%2000 == 0):
        #print(f"Appending pair dict: {pair_dict}")
        d.append(pair_dict)

    return pd.DataFrame(d).sort_values(by="P-Values").iloc[:n,]


# Calcula os retornos da carteira e armazenando em um data frame
def calculate_profit(pair, spread, threshold, par1, par2, resumo, semester, gamma):
    #print(f"Calculating profits for pair {par1}-{par2}")

    #print(f"Spread series: {spread}")

    date_format = "%Y-%m-%d"

    log_ret = spread.diff() # log return eh o incremento
    #print(f"log_ret len: {len(log_ret)} | variable: {log_ret}")
    dias = spread.index
    #print(f"Dias len: {len(dias)} | variable: {dias}")
    z_score = (spread-spread.mean())/spread.std()
    #z_score.plot() # Deixa a memória RAM muito sobrecarregada
    #print(f"Z-score index: {z_score.index} | variable: {z_score}")
    portfolio_return = []
    pos = 0 # 0: sem posição aberta
            # 1: Comprei o meu portfolio h = (1,-gamma)
            # -1: Vendi o meu portfolio h = -(1,-gamma)

    dias_abertura = []
    dias_fechamento = []

    count = 0
    dia_abertura = 0
    dia_fechamento = 0

    closing_threshold = 0.0

    for i in range(1, len(z_score)):

        if (z_score.iloc[i][0] > threshold) and (pos == 0):
            # Posição fechada no par e com sinal short 1st e long 2nd
            pos = -1

            count += 1
            dia_abertura = dias[i] - dias[0]
            retornos_op = []


        elif (z_score.iloc[i][0] < -threshold)  and (pos == 0):
            # Posição fechada no par e com sinal de long 1st e short 2nd
            pos = 1

            count += 1
            dia_abertura = dias[i] - dias[0]
            retornos_op = []

        else:
            #print(f"Dia {i} | Pos {pos} | log_ret {log_ret[i]} | S1 return {returns[par1][i]} | S2 return {returns[par2][i]} | Net {pos*(returns[par1][i] - gamma*returns[par2][i])}")
            if (pos != 0) and ((dias[i] - dias[0] - dia_abertura) == duration_limit):
                #Fechando operações maiores que 50 dias
                portfolio_return.append(log_ret.iloc[i][0]*pos)
                pos = 0
                dia_fechamento = dias[i] - dias[0]
                delta_dias = dia_fechamento - dia_abertura
                if sum(retornos_op) < stop_loss:
                    print(f"Sum: {sum(retornos_op)}")
                    retorno_op = stop_loss
                    print(f"Retorno_op: {retorno_op}")
                else:
                    retornos_op.append(log_ret.iloc[i][0]*pos)
                    retorno_op = pd.Series(retornos_op).sum()

                resumo.append([count, semester, dia_abertura, dia_fechamento, delta_dias, retorno_op, par1, par2, True])


            elif (pos == 1) and (z_score.iloc[i][0] >= -closing_threshold or sum(retornos_op) < stop_loss):
                # Posição vendida aberta no par e com sinal de convergência
                portfolio_return.append(log_ret.iloc[i][0]*pos)
                pos = 0

                dia_fechamento = dias[i] - dias[0]
                delta_dias = dia_fechamento - dia_abertura
                if sum(retornos_op) < stop_loss:
                    print(f"Sum: {sum(retornos_op)}")
                    retorno_op = stop_loss
                    print(f"Retorno_op: {retorno_op}")
                else:
                    retornos_op.append(log_ret.iloc[i][0]*pos)
                    retorno_op = pd.Series(retornos_op).sum()

                resumo.append([count, semester, dia_abertura, dia_fechamento, delta_dias, retorno_op, par1, par2, True])

            elif (pos == -1) and (z_score.iloc[i][0] <= closing_threshold or sum(retornos_op) < stop_loss):
                portfolio_return.append(log_ret.iloc[i][0]*pos)
                pos = 0

                dia_fechamento = dias[i] - dias[0]
                delta_dias = dia_fechamento - dia_abertura
                if sum(retornos_op) < stop_loss:
                    print(f"Sum: {sum(retornos_op)}")
                    retorno_op = stop_loss
                    print(f"Retorno_op: {retorno_op}")
                else:
                    retornos_op.append(log_ret.iloc[i][0]*pos)
                    retorno_op = pd.Series(retornos_op).sum()

                resumo.append([count, semester, dia_abertura, dia_fechamento, delta_dias, retorno_op, par1, par2, True])

            elif (pos == 1) and (z_score.iloc[i][0] < -closing_threshold):
                # Posição vendidada aberta no par aberta e sem convergência
                portfolio_return.append(log_ret.iloc[i][0]*pos)
                retornos_op.append(log_ret.iloc[i][0]*pos)


            elif (pos == -1) and (z_score.iloc[i][0] > closing_threshold):
                portfolio_return.append(log_ret.iloc[i][0]*pos)
                retornos_op.append(log_ret.iloc[i][0]*pos)

            else:
                # Sem posição aberta e nem sinal de entrada

                if pos != 0:
                    dia_fechamento = dias[i] - dias[0]
                    delta_dias = dia_fechamento - dia_abertura
                    retornos_op.append(log_ret.iloc[i][0]*pos)
                    retorno_op = pd.Series(retornos_op).sum()

                    resumo.append([count, semester, dia_abertura, dia_fechamento, delta_dias, retorno_op, par1, par2, True])

                pos = 0

    if pos != 0:
        # Operação sem convergência
        pos = 0

        dia_fechamento = dias[i] - dias[0]
        delta_dias = dia_fechamento - dia_abertura
        retorno_op = pd.Series(retornos_op).sum()
        print(f"Par {par1}-{par2} sem convergência, retorno_op: {retorno_op}")
        resumo.append([count, semester, dia_abertura, dia_fechamento, delta_dias, retorno_op, par1, par2, False])

    #print(f"Total return: {sum(pair_returns)} | Pair returns: {pair_returns}")
    #print(f"Conversão do par: {pos}")
    total_ret = pd.Series(portfolio_return).sum()

    return total_ret, resumo


# Calcula o expoente de hurst
def get_hurst_exponent(time_series):

    # Definindo o intervalo de taus
    max_tau = round(len(time_series)/4)
    taus = range(2, max_tau)

    # Calculando a variável k
    k = [np.std(np.subtract(time_series[tau:], time_series[:-tau])) for tau in taus]

    'To calculate the Hurst exponent, we first calculate the standard deviation of the differences between a series and its lagged version, for a range of possible lags.'

    # Calculate the slope of the log plot -> the Hurst Exponent
    reg = np.polyfit(np.log(taus), np.log(k), 1)

    'We then estimate the Hurst exponent as the slope of the log-log plot of the number of lags versus the mentioned standard deviations.'

    return reg[0]

# %% [markdown]
# ## Leitura das séries de Preços e retornos das ações,também dos semestres do período total

# %%
no_pairs = 100
duration_limit = 50
years = 2023 - 1995
threshold = 2

alpha = 0.05

days, num_assets = np.shape(preços)

stop_loss = float('-inf')

# %%
np.shape(preços)
# Out:
# (7563, 212)

# %% [markdown]
# ## Execução da Estratégia:

# %%
results = []
resumos = []

coint_pairs_df = []

inicio = 0

for big_loop in range(0, len(semestres) - 3):
    print(f"Starting period {big_loop} | Past days: {inicio}")

    # Listando os dias dos intervalos
    inicio = (Datas == semestres['Data'][big_loop]).query("Data == True").index[0]
    twelve_months = (Datas == semestres['Data'][big_loop + 2]).query("Data == True").index[0]
    six_months = (Datas == semestres['Data'][big_loop + 3]).query("Data == True").index[0]

    # Limpeza das ações não listadas no período
    ps = log_data.iloc[inicio:twelve_months,:].dropna(how="any",axis=1) # Só usar se der erro
    listed = ps.iloc[0]
    listed_num = np.sum(listed.value_counts())
    print(f"Listed stocks for the period: {listed_num}")

    log_data_filtrado = log_data.columns.isin(listed.index)
    listed_indexes = np.where(log_data_filtrado > 0)[0]
    listed_stocks = listed.index

    # Achando os pares cointegrados
    #ps = log_data.iloc[inicio:twelve_months,listed_indexes]
    #ps = log_data.iloc[inicio:twelve_months,listed_indexes].dropna(how="any",axis=1) # Só usar se der erro
    pvalues, gammas = find_cointegrated_pairs_mod(ps)
    print(pvalues.shape,gammas.shape)
    cp = top_coint_pairs(ps, pvalues, gammas, alpha, big_loop,no_pairs)
    coint_pairs_df.append(cp)
    #print(coint_pairs_df)
# Out:
# Starting period 0 | Past days: 0
# Listed stocks for the period: 57
# Finding cointegrated pairs for shape (260, 57)
# Finished pairs for stock VALE3
# Finished pairs for stock SUZB5
# (57, 57) (57, 57)
# Starting period 1 | Past days: 129
# Listed stocks for the period: 60
# Finding cointegrated pairs for shape (262, 60)
# Finished pairs for stock VALE3
# Finished pairs for stock SHAP4
# (60, 60) (60, 60)
# Starting period 2 | Past days: 259
# Listed stocks for the period: 60
# Finding cointegrated pairs for shape (261, 60)
# Finished pairs for stock VALE3
# Finished pairs for stock SHAP4
# (60, 60) (60, 60)
# Starting period 3 | Past days: 389
# Listed stocks for the period: 63
# Finding cointegrated pairs for shape (261, 63)
# Finished pairs for stock VALE3
# Finished pairs for stock PMAM4
# (63, 63) (63, 63)
# Starting period 4 | Past days: 521
# Listed stocks for the period: 62
# Finding cointegrated pairs for shape (261, 62)
# Finished pairs for stock VALE3
# Finished pairs for stock PALF3
# (62, 62) (62, 62)
# Starting period 5 | Past days: 650
# Listed stocks for the period: 60
# Finding cointegrated pairs for shape (261, 60)
# Finished pairs for stock VALE3
# Finished pairs for stock CSTB4
# (60, 60) (60, 60)
# Starting period 6 | Past days: 782
# Listed stocks for the period: 69
# Finding cointegrated pairs for shape (261, 69)
# Finished pairs for stock VALE3
# Finished pairs for stock PCAR4
# (69, 69) (69, 69)
# Starting period 7 | Past days: 911
# Listed stocks for the period: 90
# Finding cointegrated pairs for shape (261, 90)
# Finished pairs for stock VALE3
# Finished pairs for stock PTIP4
# (90, 90) (90, 90)
# Starting period 8 | Past days: 1043
# Listed stocks for the period: 90
# Finding cointegrated pairs for shape (262, 90)
# Finished pairs for stock VALE3
# Finished pairs for stock VCPA4
# (90, 90) (90, 90)
# Starting period 9 | Past days: 1172
# Listed stocks for the period: 93
# Finding cointegrated pairs for shape (260, 93)
# Finished pairs for stock VALE3
# Finished pairs for stock ERIC4
# (93, 93) (93, 93)
# Starting period 10 | Past days: 1304
# Listed stocks for the period: 93
# Finding cointegrated pairs for shape (260, 93)
# Finished pairs for stock VALE3
# Finished pairs for stock VCPA4
# (93, 93) (93, 93)
# Starting period 11 | Past days: 1434
# Listed stocks for the period: 91
# Finding cointegrated pairs for shape (261, 91)
# Finished pairs for stock VALE3
# Finished pairs for stock INEP4
# (91, 91) (91, 91)
# Starting period 12 | Past days: 1564
# Listed stocks for the period: 86
# Finding cointegrated pairs for shape (260, 86)
# Finished pairs for stock VALE3
# Finished pairs for stock PTIP4
# (86, 86) (86, 86)
# Starting period 13 | Past days: 1694
# Listed stocks for the period: 86
# Finding cointegrated pairs for shape (261, 86)
# Finished pairs for stock VALE3
# Finished pairs for stock KLBN4
# (86, 86) (86, 86)
# Starting period 14 | Past days: 1825
# Listed stocks for the period: 87
# Finding cointegrated pairs for shape (261, 87)
# Finished pairs for stock VALE3
# Finished pairs for stock PTIP4
# (87, 87) (87, 87)
# Starting period 15 | Past days: 1954
# Listed stocks for the period: 87
# Finding cointegrated pairs for shape (261, 87)
# Finished pairs for stock VALE3
# Finished pairs for stock PTIP4
# (87, 87) (87, 87)
# Starting period 16 | Past days: 2086
# Listed stocks for the period: 90
# Finding cointegrated pairs for shape (262, 90)
# Finished pairs for stock VALE3
# Finished pairs for stock GEPA4
# (90, 90) (90, 90)
# Starting period 17 | Past days: 2215
# Listed stocks for the period: 89
# Finding cointegrated pairs for shape (262, 89)
# Finished pairs for stock VALE3
# Finished pairs for stock VCPA4
# (89, 89) (89, 89)
# Starting period 18 | Past days: 2347
# Listed stocks for the period: 88
# Finding cointegrated pairs for shape (261, 88)
# Finished pairs for stock VALE3
# Finished pairs for stock TBLE6
# (88, 88) (88, 88)
# Starting period 19 | Past days: 2477
# Listed stocks for the period: 86
# Finding cointegrated pairs for shape (260, 86)
# Finished pairs for stock VALE3
# Finished pairs for stock EBTP4
# (86, 86) (86, 86)
# Starting period 20 | Past days: 2609
# Listed stocks for the period: 83
# Finding cointegrated pairs for shape (261, 83)
# Finished pairs for stock VALE3
# Finished pairs for stock INEP4
# (83, 83) (83, 83)
# Starting period 21 | Past days: 2738
# Listed stocks for the period: 90
# Finding cointegrated pairs for shape (260, 90)
# Finished pairs for stock VALE3
# Finished pairs for stock DURA4
# (90, 90) (90, 90)
# Starting period 22 | Past days: 2869
# Listed stocks for the period: 94
# Finding cointegrated pairs for shape (260, 94)
# Finished pairs for stock VALE3
# Finished pairs for stock CPSL3
# (94, 94) (94, 94)
# Starting period 23 | Past days: 2999
# Listed stocks for the period: 99
# Finding cointegrated pairs for shape (261, 99)
# Finished pairs for stock VALE3
# Finished pairs for stock CESP5
# (99, 99) (99, 99)
# Starting period 24 | Past days: 3129
# Listed stocks for the period: 109
# Finding cointegrated pairs for shape (261, 109)
# Finished pairs for stock VALE3
# Finished pairs for stock CTAX4
# Finished pairs for stock TCSL4
# (109, 109) (109, 109)
# Starting period 25 | Past days: 3259
# Listed stocks for the period: 118
# Finding cointegrated pairs for shape (262, 118)
# Finished pairs for stock VALE3
# Finished pairs for stock DXCO3
# Finished pairs for stock TAMM4
# (118, 118) (118, 118)
# Starting period 26 | Past days: 3390
# Listed stocks for the period: 121
# Finding cointegrated pairs for shape (261, 121)
# Finished pairs for stock VALE3
# Finished pairs for stock MRFG3
# Finished pairs for stock SDIA4
# (121, 121) (121, 121)
# Starting period 27 | Past days: 3520
# Listed stocks for the period: 117
# Finding cointegrated pairs for shape (261, 117)
# Finished pairs for stock VALE3
# Finished pairs for stock YDUQ3
# Finished pairs for stock SYNE3
# (117, 117) (117, 117)
# Starting period 28 | Past days: 3652
# Listed stocks for the period: 117
# Finding cointegrated pairs for shape (261, 117)
# Finished pairs for stock VALE3
# Finished pairs for stock ALPA4
# Finished pairs for stock SYNE3
# (117, 117) (117, 117)
# Starting period 29 | Past days: 3781
# Listed stocks for the period: 121
# Finding cointegrated pairs for shape (261, 121)
# Finished pairs for stock VALE3
# Finished pairs for stock USIM5
# Finished pairs for stock RSID3
# (121, 121) (121, 121)
# Starting period 30 | Past days: 3913
# Listed stocks for the period: 119
# Finding cointegrated pairs for shape (261, 119)
# Finished pairs for stock VALE3
# Finished pairs for stock CYRE3
# Finished pairs for stock RSID3
# (119, 119) (119, 119)
# Starting period 31 | Past days: 4042
# Listed stocks for the period: 118
# Finding cointegrated pairs for shape (260, 118)
# Finished pairs for stock VALE3
# Finished pairs for stock USIM5
# Finished pairs for stock RDCD3
# (118, 118) (118, 118)
# Starting period 32 | Past days: 4174
# Listed stocks for the period: 117
# Finding cointegrated pairs for shape (261, 117)
# Finished pairs for stock VALE3
# Finished pairs for stock SLCE3
# Finished pairs for stock PDGR3
# (117, 117) (117, 117)
# Starting period 33 | Past days: 4303
# Listed stocks for the period: 114
# Finding cointegrated pairs for shape (261, 114)
# Finished pairs for stock VALE3
# Finished pairs for stock ENBR3
# Finished pairs for stock PDGR3
# (114, 114) (114, 114)
# Starting period 34 | Past days: 4434
# Listed stocks for the period: 116
# Finding cointegrated pairs for shape (260, 116)
# Finished pairs for stock VALE3
# Finished pairs for stock ENBR3
# Finished pairs for stock PCAR4
# (116, 116) (116, 116)
# Starting period 35 | Past days: 4564
# Listed stocks for the period: 115
# Finding cointegrated pairs for shape (261, 115)
# Finished pairs for stock VALE3
# Finished pairs for stock ENBR3
# Finished pairs for stock PCAR4
# (115, 115) (115, 115)
# Starting period 36 | Past days: 4695
# Listed stocks for the period: 118
# Finding cointegrated pairs for shape (261, 118)
# Finished pairs for stock VALE3
# Finished pairs for stock CIEL3
# Finished pairs for stock OIBR3
# (118, 118) (118, 118)
# Starting period 37 | Past days: 4824
# Listed stocks for the period: 117
# Finding cointegrated pairs for shape (261, 117)
# Finished pairs for stock VALE3
# Finished pairs for stock CIEL3
# Finished pairs for stock PCAR4
# (117, 117) (117, 117)
# Starting period 38 | Past days: 4956
# Listed stocks for the period: 114
# Finding cointegrated pairs for shape (261, 114)
# Finished pairs for stock VALE3
# Finished pairs for stock ARZZ3
# Finished pairs for stock PRML3
# (114, 114) (114, 114)
# Starting period 39 | Past days: 5085
# Listed stocks for the period: 114
# Finding cointegrated pairs for shape (261, 114)
# Finished pairs for stock VALE3
# Finished pairs for stock ARZZ3
# Finished pairs for stock PDGR3
# (114, 114) (114, 114)
# Starting period 40 | Past days: 5217
# Listed stocks for the period: 113
# Finding cointegrated pairs for shape (262, 113)
# Finished pairs for stock VALE3
# Finished pairs for stock MULT3
# Finished pairs for stock PRML3
# (113, 113) (113, 113)
# Starting period 41 | Past days: 5346
# Listed stocks for the period: 115
# Finding cointegrated pairs for shape (261, 115)
# Finished pairs for stock VALE3
# Finished pairs for stock MULT3
# Finished pairs for stock PCAR4
# (115, 115) (115, 115)
# Starting period 42 | Past days: 5478
# Listed stocks for the period: 113
# Finding cointegrated pairs for shape (261, 113)
# Finished pairs for stock VALE3
# Finished pairs for stock MULT3
# Finished pairs for stock PDGR3
# (113, 113) (113, 113)
# Starting period 43 | Past days: 5608
# Listed stocks for the period: 110
# Finding cointegrated pairs for shape (260, 110)
# Finished pairs for stock VALE3
# Finished pairs for stock MULT3
# Finished pairs for stock PRML3
# (110, 110) (110, 110)
# Starting period 44 | Past days: 5739
# Listed stocks for the period: 113
# Finding cointegrated pairs for shape (260, 113)
# Finished pairs for stock VALE3
# Finished pairs for stock SULA11
# Finished pairs for stock OIBR4
# (113, 113) (113, 113)
# Starting period 45 | Past days: 5869
# Listed stocks for the period: 117
# Finding cointegrated pairs for shape (261, 117)
# Finished pairs for stock VALE3
# Finished pairs for stock BRAP4
# Finished pairs for stock POMO4
# (117, 117) (117, 117)
# Starting period 46 | Past days: 5999
# Listed stocks for the period: 118
# Finding cointegrated pairs for shape (260, 118)
# Finished pairs for stock VALE3
# Finished pairs for stock BRML3
# Finished pairs for stock LCAM3
# (118, 118) (118, 118)
# Starting period 47 | Past days: 6129
# Listed stocks for the period: 119
# Finding cointegrated pairs for shape (261, 119)
# Finished pairs for stock VALE3
# Finished pairs for stock BRML3
# Finished pairs for stock LCAM3
# (119, 119) (119, 119)
# Starting period 48 | Past days: 6260
# Listed stocks for the period: 119
# Finding cointegrated pairs for shape (262, 119)
# Finished pairs for stock VALE3
# Finished pairs for stock BRML3
# Finished pairs for stock LCAM3
# (119, 119) (119, 119)
# Starting period 49 | Past days: 6389
# Listed stocks for the period: 119
# Finding cointegrated pairs for shape (262, 119)
# Finished pairs for stock VALE3
# Finished pairs for stock BRML3
# Finished pairs for stock LIGT3
# (119, 119) (119, 119)
# Starting period 50 | Past days: 6521
# Listed stocks for the period: 119
# Finding cointegrated pairs for shape (261, 119)
# Finished pairs for stock VALE3
# Finished pairs for stock BRML3
# Finished pairs for stock JHSF3
# (119, 119) (119, 119)
# Starting period 51 | Past days: 6651
# Listed stocks for the period: 122
# Finding cointegrated pairs for shape (261, 122)
# Finished pairs for stock VALE3
# Finished pairs for stock BRKM5
# Finished pairs for stock GEPA4
# (122, 122) (122, 122)
# Starting period 52 | Past days: 6783
# Listed stocks for the period: 121
# Finding cointegrated pairs for shape (261, 121)
# Finished pairs for stock VALE3
# Finished pairs for stock TAEE11
# Finished pairs for stock GFSA3
# (121, 121) (121, 121)
# Starting period 53 | Past days: 6912
# Listed stocks for the period: 121
# Finding cointegrated pairs for shape (260, 121)
# Finished pairs for stock VALE3
# Finished pairs for stock TAEE11
# Finished pairs for stock GFSA3
# (121, 121) (121, 121)
# Starting period 54 | Past days: 7044
# Listed stocks for the period: 118
# Finding cointegrated pairs for shape (261, 118)
# Finished pairs for stock VALE3
# Finished pairs for stock TAEE11
# Finished pairs for stock INEP4
# (118, 118) (118, 118)

# %%
# Vendo o Lucro da estratégia
inicio = 0

for big_loop in range(0, len(semestres) - 3):
    print(f"Starting period {big_loop} | Past days: {inicio}")

    coint_pairs_sem_df = coint_pairs_df[big_loop]

    # Listando os dias dos intervalos
    inicio = (Datas == semestres['Data'][big_loop]).query("Data == True").index[0]
    twelve_months = (Datas == semestres['Data'][big_loop + 2]).query("Data == True").index[0]
    six_months = (Datas == semestres['Data'][big_loop + 3]).query("Data == True").index[0]

    resultado = []
    for i in range(0,coint_pairs_sem_df.shape[0]):
        S1_name = coint_pairs_sem_df.iloc[i, 0]
        S2_name = coint_pairs_sem_df.iloc[i, 1]
        gamma_1_2 = coint_pairs_sem_df.iloc[i, 3]

        #Aqui tá o problema das datas:
        S1 = log_data[S1_name].iloc[twelve_months:six_months] # periodo de teste
        S2 = log_data[S2_name].iloc[twelve_months:six_months] # periodo de teste

        #spread, convertendo Datas para nºs de dias
        spread_ = S1 - gamma_1_2*S2
        spread_.name = "spread"
        spread = pd.merge(spread_,Datas, on="Data")
        spread.index = spread['indice']
        spread.drop(['Data','indice'],inplace=True,axis=1)

        #print(spread)
        # Pegando o resultado da estratégia
        #resultado.append(np.exp(calculate_profit(spread,1.65)))
        ret, resumos = calculate_profit(i, spread, threshold, S1_name, S2_name, resumos, big_loop, gamma_1_2)
    print("-------------------------------------------------")
# Out:
# Starting period 0 | Past days: 0
# Par ITUB4-CMIG4 sem convergência, retorno_op: 0.15779485214685773
# Par ITUB4-BBDC4 sem convergência, retorno_op: 0.01114079541008528
# Par VIVT3-PTIP4 sem convergência, retorno_op: -0.05136986627720619
# Par VIVT3-WHMT3 sem convergência, retorno_op: -0.04503597499916823
# Par VIVT3-VIVT4 sem convergência, retorno_op: -0.0400030201690717
# Par CSNA3-INEP4 sem convergência, retorno_op: -0.078153154069863
# Par INEP4-BRDT4-old sem convergência, retorno_op: -0.2530189042818489
# Par PETR3-DURA4 sem convergência, retorno_op: 0.20505776105662554
# Par AMBV4-ERIC4 sem convergência, retorno_op: 0.048039154209069124
# Par VCPA4-SHAP4 sem convergência, retorno_op: 0.04659312816807193
# Par OIBR4-CSTB4 sem convergência, retorno_op: 0.07216724189414148
# -------------------------------------------------
# Starting period 2 | Past days: 259
# Par BRKM5-CMIG3 sem convergência, retorno_op: 0.48705470538863604
# Par VALE3-BRKM5 sem convergência, retorno_op: 1.2954964658416694
# Par CSNA3-BRKM5 sem convergência, retorno_op: 3.713265131797807
# Par BBAS4-UNIP6 sem convergência, retorno_op: -0.12037370909618605
# Par BRKM5-SHAP4 sem convergência, retorno_op: 0.43865676725847724
# Par BRKM5-CMET4 sem convergência, retorno_op: 0.42246098547517796
# Par BBDC3-AMBV4 sem convergência, retorno_op: 0
# Par ABEV3-BRKM5 sem convergência, retorno_op: 2.953595763979817
# Par BRKM5-CEVA4 sem convergência, retorno_op: 0.4459222749061812
# Par USIM5-VALE5 sem convergência, retorno_op: 0.055862024201957905
# Par BRKM5-POMO4 sem convergência, retorno_op: 0.42899754811860724
# Par ITUB4-BRKM5 sem convergência, retorno_op: 2.816612033723186
# Par REPA4-LAME4 sem convergência, retorno_op: -0.25710093931136946
# Par ABEV3-BBDC3 sem convergência, retorno_op: 0
# Par ITSA4-BRKM5 sem convergência, retorno_op: 4.828140348310906
# Par BRKM5-CSTB4 sem convergência, retorno_op: 0.44962761540003315
# Par BRKM5-BRDT4-old sem convergência, retorno_op: 0.45673618184159026
# Par BRKM5-BBAS4 sem convergência, retorno_op: 0.4459209074114614
# Par BRKM5-BESP4 sem convergência, retorno_op: 0.4542419445483956
# Par BRKM5-REPA4 sem convergência, retorno_op: 0.43591965550503353
# Par BRKM5-KLBN4 sem convergência, retorno_op: 0.42813268644020974
# Par BRKM5-AMBV4 sem convergência, retorno_op: 0.4904881934905456
# Par BBDC4-BRKM5 sem convergência, retorno_op: 2.347996454194736
# Par BRKM5-PALF3 sem convergência, retorno_op: 0.4217318448710504
# Par CMIG4-BRKM5 sem convergência, retorno_op: 1.8952793929702167
# Par BRKM5-INEP4 sem convergência, retorno_op: 0.42591636119592746
# Par BRKM5-OIBR4 sem convergência, retorno_op: 0.41127917617345044
# Par BRKM5-ERIC4 sem convergência, retorno_op: 0.4544059702290297
# Par BRKM5-OIBR3 sem convergência, retorno_op: 0.4178066417024724
# Par BRKM5-TMAR6 sem convergência, retorno_op: 0.4142964676728489
# Par BRKM5-SDIA4 sem convergência, retorno_op: 0.4768597597251889
# Par VCPA4-VIVT4 sem convergência, retorno_op: 0.060772667172644734
# Par GGBR4-CPSL3 sem convergência, retorno_op: 0.8397430016724508
# Par CPSL3-SUZB5 sem convergência, retorno_op: 0.16638450096907964
# Par GOAU4-BRKM5 sem convergência, retorno_op: 3.262957899815576
# Par PETR4-PETR3 sem convergência, retorno_op: 0
# Par BRKM5-CRUZ3 sem convergência, retorno_op: 0.4748574219862768
# Par CPSL3-SDIA4 sem convergência, retorno_op: 0.22293358610990743
# Par BRKM5-PMAM4 sem convergência, retorno_op: 0.4211160005696953
# Par GGBR4-BRKM5 sem convergência, retorno_op: 3.521029585192538
# Par ITSA4-KLBN4 sem convergência, retorno_op: -0.09610953139818301
# Par PCAR4-PALF3 sem convergência, retorno_op: 0.2682795209322859
# Par BBAS3-BRKM5 sem convergência, retorno_op: 0.9509929063433835
# -------------------------------------------------
# Starting period 3 | Past days: 389
# Par ABEV3-CMIG3 sem convergência, retorno_op: 0.14902584505946437
# Par CMIG3-BRDT4-old sem convergência, retorno_op: 0.03589010473587262
# Par BBAS4-CMIG3 sem convergência, retorno_op: 0.11204170349177556
# Par ITSA4-CMIG3 sem convergência, retorno_op: 0.2317505182955446
# Par CMIG4-CRUZ3 sem convergência, retorno_op: 0.15776108067997852
# Par CLSC4-OIBR4 sem convergência, retorno_op: 0.02579923737006462
# Par CMET4-CMIG3 sem convergência, retorno_op: 0.17135959981589055
# Par CEVA4-CMIG3 sem convergência, retorno_op: 0.26197615845851274
# Par REPA4-PALF3 sem convergência, retorno_op: 0.11467606574875866
# Par ALPA4-CMIG3 sem convergência, retorno_op: 0.1318514542547402
# Par ITSA4-CMIG4 sem convergência, retorno_op: 0.36063990643083255
# Par CMIG3-CSTB4 sem convergência, retorno_op: 0.0559224205637987
# Par CMIG3-SHAP4 sem convergência, retorno_op: 0.07184704730232316
# Par CMIG3-KLBN4 sem convergência, retorno_op: 0.07975550673011034
# Par CLSC4-REPA4 sem convergência, retorno_op: 0
# Par ITUB4-CMIG4 sem convergência, retorno_op: 0.06743753996151525
# Par VCPA4-VIVT4 sem convergência, retorno_op: 0.06571690687583132
# Par ELET6-INEP4 sem convergência, retorno_op: 0.009108986398655539
# Par CMIG3-POMO4 sem convergência, retorno_op: 0.044338919508213115
# Par CMIG3-UNIP6 sem convergência, retorno_op: 0.07473545686500072
# Par LIPR3-SDIA4 sem convergência, retorno_op: 0.03247130284315669
# Par BBDC4-CMIG4 sem convergência, retorno_op: 0.0536425026835039
# Par ITUB4-CSTB4 sem convergência, retorno_op: 0.1093779111047759
# Par CLSC4-CMIG3 sem convergência, retorno_op: 0.15685664516951792
# Par ELET3-CMIG3 sem convergência, retorno_op: 0.11009889213139945
# Par CMIG3-LIGT3 sem convergência, retorno_op: 0.04309562356568741
# Par CMIG4-CMET4 sem convergência, retorno_op: 0.06544544006571484
# Par CSNA3-CMIG3 sem convergência, retorno_op: 0.12187456962100152
# Par CESP5-INEP4 sem convergência, retorno_op: 0
# Par ABEV3-BRDT4-old sem convergência, retorno_op: 0.03268921483728571
# Par CMIG3-LAME4 sem convergência, retorno_op: 0.0657085626134688
# Par PETR3-SDIA4 sem convergência, retorno_op: 0.0035302148049300985
# Par CLSC4-PTIP4 sem convergência, retorno_op: 0.1254416404802554
# Par ITUB4-CMET4 sem convergência, retorno_op: 0.08097786587140243
# Par CMIG4-GOAU4 sem convergência, retorno_op: 0.11095781903710589
# Par CMIG4-BRDT4-old sem convergência, retorno_op: 0.10818354898437033
# Par CMIG4-BBAS4 sem convergência, retorno_op: 0.10388787741944572
# Par BBAS3-LIPR3 sem convergência, retorno_op: 0.007022488943811966
# Par CMIG4-PMAM4 sem convergência, retorno_op: 0.11922779929675564
# Par PETR4-PETR3 sem convergência, retorno_op: 0
# Par INEP4-VIVT4 sem convergência, retorno_op: 0.12464826846917898
# Par CMIG3-PALF3 sem convergência, retorno_op: 0.06006865596720368
# Par ALPA4-POMO4 sem convergência, retorno_op: 0.17924119698718233
# Par ITUB4-ELET3 sem convergência, retorno_op: 0.09376682613649834
# Par ITSA4-CSNA3 sem convergência, retorno_op: 0.09305123333197507
# Par ELET3-VIVT4 sem convergência, retorno_op: 0.03208695390162131
# Par ELET3-ALPA4 sem convergência, retorno_op: 0.13106164091867956
# -------------------------------------------------
# Starting period 4 | Past days: 521
# Par VIVT3-DURA4 sem convergência, retorno_op: 0.047748668446174536
# Par VALE3-GOAU4 sem convergência, retorno_op: 0.04035979283300151
# Par GGBR4-GOAU4 sem convergência, retorno_op: 0.0520565862873934
# Par ARCE3-ARCE4 sem convergência, retorno_op: -0.13307613147256442
# Par PCAR4-VIVT4 sem convergência, retorno_op: 0.015389269291559149
# Par VIVT3-CLSC4 sem convergência, retorno_op: 0.17028999127046962
# Par BBAS3-ARCE3 sem convergência, retorno_op: -0.2520518506877958
# Par BBDC3-CSNA3 sem convergência, retorno_op: -0.04264105992725997
# Par VIVT3-PCAR4 sem convergência, retorno_op: 0.12455614913437596
# Par ARCE3-VALE5 sem convergência, retorno_op: -0.15709942960609868
# Par UNIP6-BRDT4-old sem convergência, retorno_op: 0.09482468105079622
# Par CSNA3-UNIP6 sem convergência, retorno_op: 0
# Par BBAS3-ARCE4 sem convergência, retorno_op: 0.31217070602050767
# Par ABEV3-BBDC3 sem convergência, retorno_op: 0.05941518050684502
# -------------------------------------------------
# Starting period 5 | Past days: 650
# Par INEP4-OIBR4 sem convergência, retorno_op: 0.21146684611880007
# Par BBDC3-AMBV4 sem convergência, retorno_op: -0.02832411282344871
# Par CMET4-KLBN4 sem convergência, retorno_op: 0
# Par GOAU4-CMIG3 sem convergência, retorno_op: -0.07463726523259884
# Par BBDC4-AMBV4 sem convergência, retorno_op: -0.026837046158701083
# Par BBDC3-KLBN4 sem convergência, retorno_op: -0.06840637547864348
# -------------------------------------------------
# Starting period 6 | Past days: 782
# Par SBSP3-EMAE4 sem convergência, retorno_op: -0.027619390947023703
# Par ELET3-PCAR4 sem convergência, retorno_op: 0.1012200998797701
# Par BESP4-EPTE4 sem convergência, retorno_op: 0.020230750665759967
# Par ABEV3-CMET4 sem convergência, retorno_op: 0.028286669144065746
# Par EPTE4-BRDT4-old sem convergência, retorno_op: 0.24481407736024696
# Par BMTO4-BRDT4-old sem convergência, retorno_op: 0.039362837613831636
# Par BBDC3-BRDT4-old sem convergência, retorno_op: -0.052016534353322985
# Par BMTO4-POMO4 sem convergência, retorno_op: 0.026608468405315056
# Par ITUB4-CMIG4 sem convergência, retorno_op: 0.1856473911841009
# Par BBDC3-EPTE4 sem convergência, retorno_op: -0.014521588861742707
# Par BBDC3-BESP4 sem convergência, retorno_op: -0.00041928198312035647
# Par CMET4-KLBN4 sem convergência, retorno_op: 0.1771683781046498
# Par BBDC4-EPTE4 sem convergência, retorno_op: -0.015179412641704082
# Par ITUB4-CPLE6 sem convergência, retorno_op: 0.050471809362243825
# Par BMTO4-CSTB4 sem convergência, retorno_op: 0.03453746140239089
# Par BRKM5-EMBR4 sem convergência, retorno_op: 0.1746421748154694
# Par BBDC4-UNIP6 sem convergência, retorno_op: 0.06792891142793683
# Par ITUB4-AMBV4 sem convergência, retorno_op: 0.024138424334798014
# Par BMTO4-CEVA4 sem convergência, retorno_op: 0.009734438694141145
# Par BBDC4-CMIG3 sem convergência, retorno_op: 0.059168627710887045
# Par BMTO4-EPTE4 sem convergência, retorno_op: 0.07991345147304141
# Par ABEV3-EPTE4 sem convergência, retorno_op: -0.019729912422116636
# Par BBAS4-BMTO4 sem convergência, retorno_op: 0.03279573122609847
# Par BBDC3-CEVA4 sem convergência, retorno_op: -0.08487123133983343
# Par ITSA4-EPTE4 sem convergência, retorno_op: 0.05413630656421442
# Par BBAS3-TSPC3 sem convergência, retorno_op: 0.011006808473754293
# Par BMTO4-CMET4 sem convergência, retorno_op: 0.00926321725623691
# Par ITSA4-TMAR6 sem convergência, retorno_op: -0.1553856463901533
# Par BBDC4-CMIG4 sem convergência, retorno_op: 0.1887484980681362
# Par CMIG4-CMIG3 sem convergência, retorno_op: 0
# Par BMTO4-TMAR6 sem convergência, retorno_op: -0.040374166229827924
# Par ABEV3-TPRC6 sem convergência, retorno_op: -0.038990728028531096
# Par CPSL3-DURA4 sem convergência, retorno_op: 0.020176755456576934
# Par ABEV3-BMTO4 sem convergência, retorno_op: 0.0076560476727871585
# -------------------------------------------------
# Starting period 7 | Past days: 911
# Par ELET3-INEP4 sem convergência, retorno_op: -0.02955321784382603
# Par EGIE3-RCTB41 sem convergência, retorno_op: -0.050581616771503635
# Par ARCZ6-EPTE4 sem convergência, retorno_op: 0.17795538067243377
# Par POMO4-PALF3 sem convergência, retorno_op: 0.02491101711221999
# Par ELET3-ARCZ6 sem convergência, retorno_op: 0.14076879282766908
# Par ELET6-ARCZ6 sem convergência, retorno_op: 0.05172804485122384
# Par ARCZ6-TPRC6 sem convergência, retorno_op: 0.1541036202259629
# Par VIVT3-ARCZ6 sem convergência, retorno_op: -0.061487829496671864
# Par LIGT3-TNLP4 sem convergência, retorno_op: 0.049141307365872855
# Par ARCZ6-CLSC4 sem convergência, retorno_op: 0.12921586484929226
# Par ARCZ6-CESP5 sem convergência, retorno_op: 0.09703133553901322
# Par RSID3-VIVT4 sem convergência, retorno_op: -0.17139427273933316
# Par SUZB5-TMAR5 sem convergência, retorno_op: -0.016501884089147767
# Par SUZB5-TMAR6 sem convergência, retorno_op: 0.030251135630489534
# Par GGBR4-GOAU4 sem convergência, retorno_op: 0.01273979687425636
# Par GGBR4-ARCE3 sem convergência, retorno_op: 0.014063922965393716
# Par SUZB5-VIVO4 sem convergência, retorno_op: 0.011511619221527436
# -------------------------------------------------
# Starting period 14 | Past days: 1825
# Par ARCE3-ARCE4 sem convergência, retorno_op: 0.01108461091870927
# Par CMIG4-TELB4 sem convergência, retorno_op: 0.4396865169395452
# Par CMIG4-TELB3 sem convergência, retorno_op: 0.3329258871562475
# Par TLCP4-TMAR5 sem convergência, retorno_op: 0.0027533299317625826
# Par CCRO3-TELB3 sem convergência, retorno_op: 0.4548529399981358
# Par CMIG3-TELB3 sem convergência, retorno_op: 0.38224704529090237
# Par PETR4-GOAU4 sem convergência, retorno_op: 0.05073577030851811
# Par TLCP4-TMAR6 sem convergência, retorno_op: -0.011855339357303318
# Par BBDC3-TELB4 sem convergência, retorno_op: 0.2912647252649474
# Par BRTP3-BRTP4 sem convergência, retorno_op: 0.0367542432941006
# Par ITSA4-ALPA4 sem convergência, retorno_op: 0.04048721800833455
# Par TMAR6-TMCP4 sem convergência, retorno_op: 0.16564020318476658
# Par CLSC4-CSTB4 sem convergência, retorno_op: -0.00651257705079189
# Par OIBR4-TLCP4 sem convergência, retorno_op: 0.09066686011801028
# Par ITUB4-GOAU4 sem convergência, retorno_op: 0
# Par CCRO3-TELB4 sem convergência, retorno_op: 0.7760346553818969
# Par TLCP4-TMCP4 sem convergência, retorno_op: -0.013797667674323666
# Par BRAP4-TELB4 sem convergência, retorno_op: 0.4383036688089296
# Par PETR3-ACES4 sem convergência, retorno_op: 0.007566178938138712
# Par EBTP3-EBTP4 sem convergência, retorno_op: 0.09936387460458285
# Par OIBR3-TLCP4 sem convergência, retorno_op: 0.1324755336203225
# Par BBDC3-TELB3 sem convergência, retorno_op: 0.21464290555695537
# Par PETR3-GOAU4 sem convergência, retorno_op: 0.011377858488659798
# Par TMAR5-TMCP4 sem convergência, retorno_op: 0.14037598613186741
# Par NETC4-TCSL4 sem convergência, retorno_op: 0.1922646771972527
# Par PTIP4-NETC4 sem convergência, retorno_op: 0.36781151108756327
# Par PETR4-AMBV4 sem convergência, retorno_op: 0.03979745957917785
# -------------------------------------------------
# Starting period 15 | Past days: 1954
# Par GGBR4-BRKM5 sem convergência, retorno_op: 0.01871284534740003
# Par CPSL3-PTIP4 sem convergência, retorno_op: 0.037435191488349506
# Par CMIG4-CCRO3 sem convergência, retorno_op: 0.02711285754569337
# Par EMBR3-UBBR11 sem convergência, retorno_op: 0.024018648410670806
# Par PCAR4-TMAR6 sem convergência, retorno_op: 0.0712700811500877
# Par CRTP5-PCAR4 sem convergência, retorno_op: 0.09448657194145316
# Par PTIP4-SUZB5 sem convergência, retorno_op: 0.1873612366870432
# Par CCRO3-LAME4 sem convergência, retorno_op: -0.10835608924224965
# Par CPLE6-ALPA4 sem convergência, retorno_op: -0.006204501999090284
# Par TLCP4-TMAR6 sem convergência, retorno_op: 0.03471614728915995
# Par PETR4-GGBR4 sem convergência, retorno_op: 0.006168290603442483
# Par EMBR4-UBBR11 sem convergência, retorno_op: 0.15606457511259242
# Par EBTP3-RCTB31 sem convergência, retorno_op: 0.02129834129635988
# Par EMBR3-DURA4 sem convergência, retorno_op: 0.09553111870136233
# -------------------------------------------------
# Starting period 16 | Past days: 2086
# Par ELET3-ELET6 sem convergência, retorno_op: 0.0052675585010533155
# Par PTIP4-VALE5 sem convergência, retorno_op: -0.03694311323876143
# Par SBSP3-LIGT3 sem convergência, retorno_op: 0
# Par TSEP4-TNLP4 sem convergência, retorno_op: 0.07513639862855737
# Par SBSP3-INEP4 sem convergência, retorno_op: -0.31385151521018906
# Par BRTP3-TSEP4 sem convergência, retorno_op: 0.08081956461089623
# Par INEP4-LIGT3 sem convergência, retorno_op: -0.37885658561574664
# Par BESP4-VCPA4 sem convergência, retorno_op: -0.07753207074835533
# Par VALE3-INEP4 sem convergência, retorno_op: -0.5375088520847227
# Par TSEP4-TMAR5 sem convergência, retorno_op: 0.08934184912440601
# Par VALE3-VIVT4 sem convergência, retorno_op: 0.015366795154726054
# Par PTIP4-UBBR11 sem convergência, retorno_op: -0.024463942295372743
# Par BRTP3-PCAR4 sem convergência, retorno_op: 0.09523963070673158
# Par TSEP4-TNLP3 sem convergência, retorno_op: 0.04381003715856302
# Par ITSA4-POMO4 sem convergência, retorno_op: 0.04473485290218404
# Par CRTP5-TNLP3 sem convergência, retorno_op: 0.004472330925325174
# Par INEP4-VALE5 sem convergência, retorno_op: -0.4216706310086693
# Par BRKM5-INEP4 sem convergência, retorno_op: -0.74709766082682
# Par VIVT3-INEP4 sem convergência, retorno_op: -0.5483805859878459
# Par VALE3-TSEP4 sem convergência, retorno_op: 0.04034390438902036
# Par ELET6-INEP4 sem convergência, retorno_op: -0.670522433779696
# Par ELET3-INEP4 sem convergência, retorno_op: -0.8415917675208413
# Par ARCZ6-BESP4 sem convergência, retorno_op: -0.09452021328671867
# Par PTIP4-CRUZ3 sem convergência, retorno_op: -0.09821099205002648
# Par CRUZ3-VIVT4 sem convergência, retorno_op: 0.05266016906280546
# Par INEP4-UBBR11 sem convergência, retorno_op: -0.3920510073218386
# Par INEP4-TCSL4 sem convergência, retorno_op: -0.4391615275746783
# -------------------------------------------------
# Starting period 17 | Past days: 2215
# Par GETI4-UNIP6 sem convergência, retorno_op: -0.03559993902923053
# Par GETI4-USIM3 sem convergência, retorno_op: -0.0038709485990430226
# Par TBLE6-PMAM4 sem convergência, retorno_op: -0.04782577528489784
# Par GETI4-AMBV4 sem convergência, retorno_op: 0.08272251856733037
# Par BRKM5-GETI4 sem convergência, retorno_op: 0.032042201446311314
# Par LIGT3-PCAR4 sem convergência, retorno_op: 0.10557576637249166
# Par GETI4-DURA4 sem convergência, retorno_op: 0
# Par EMBR4-SUZB5 sem convergência, retorno_op: -0.04712608262192308
# Par GETI4-PMAM4 sem convergência, retorno_op: -0.01151798361978873
# Par EMBR3-VIVO4 sem convergência, retorno_op: 0.009537494829573667
# Par USIM5-GETI4 sem convergência, retorno_op: -0.014448714634249793
# Par GETI4-PTIP4 sem convergência, retorno_op: 0.002298604874960919
# Par VIVT4-TNLP3 sem convergência, retorno_op: 0.027944231057247748
# Par LIGT3-TMAR5 sem convergência, retorno_op: 0.17583288369259087
# Par PETR3-PMAM4 sem convergência, retorno_op: -0.011434336847824023
# Par EMBR4-VIVO4 sem convergência, retorno_op: -0.044785034659894585
# Par EMBR3-VIVO3 sem convergência, retorno_op: -0.008322275453872763
# Par GETI4-CGAS5 sem convergência, retorno_op: -0.007483936002530833
# Par LIGT3-VIVT4 sem convergência, retorno_op: 0.21836297486908407
# Par ELET6-ARCE4 sem convergência, retorno_op: 0.11611295964375046
# Par PETR4-BRKM5 sem convergência, retorno_op: -0.022374262563015668
# -------------------------------------------------
# Starting period 18 | Past days: 2347
# Par BRTP3-TMAR5 sem convergência, retorno_op: 0
# Par CRTP5-DURA4 sem convergência, retorno_op: 0.06737108377694057
# Par VIVT3-BRTP3 sem convergência, retorno_op: -0.04541459103200296
# Par GOLL4-BRTP3 sem convergência, retorno_op: -0.20559192606708043
# Par KLBN4-POMO4 sem convergência, retorno_op: -0.044158220785709634
# Par VIVT3-EBTP4 sem convergência, retorno_op: 0
# Par OIBR4-UGPA4 sem convergência, retorno_op: 0.19756726608216102
# Par BRTP4-DURA4 sem convergência, retorno_op: -0.03709412441480664
# Par GOLL4-CPSL3 sem convergência, retorno_op: -0.049554682973086184
# Par UGPA4-VIVO3 sem convergência, retorno_op: -0.016014093748329294
# Par EMBR3-CPSL3 sem convergência, retorno_op: 0.03635221095709262
# Par EMBR3-BRTP3 sem convergência, retorno_op: -0.06602012354892528
# Par BRTP3-TMAR6 sem convergência, retorno_op: -0.05087233035694538
# Par VIVT3-GOLL4 sem convergência, retorno_op: -0.0024715633987115737
# Par TMAR6-TCSL4 sem convergência, retorno_op: -0.02526721910546126
# Par UBBR11-VALE5 sem convergência, retorno_op: 0.007486044211533205
# Par ITUB4-TIMS3 sem convergência, retorno_op: 0.061770927658522545
# Par BRTP3-VIVT4 sem convergência, retorno_op: -0.03861270746521317
# Par TLCP4-UNIP6 sem convergência, retorno_op: -0.06296318593769801
# Par VALE3-UBBR11 sem convergência, retorno_op: 0.008567374364675473
# Par BRTP3-EMBR4 sem convergência, retorno_op: -0.08406136550863641
# Par CPSL3-UGPA4 sem convergência, retorno_op: 0.01656495770179811
# Par TSEP4-UNIP6 sem convergência, retorno_op: 0.0387137883963482
# Par GOAU4-SUZB5 sem convergência, retorno_op: 0.01769152099479432
# Par BRTP3-TCSL4 sem convergência, retorno_op: -0.12781330004066493
# Par TELB4-TCSL4 sem convergência, retorno_op: 0.04822368497689711
# -------------------------------------------------
# Starting period 19 | Past days: 2477
# Par ITUB4-NETC4 sem convergência, retorno_op: 0.10992490020614243
# Par BRTP4-OIBR3 sem convergência, retorno_op: 0.04346010271701717
# Par NTCO3-NETC4 sem convergência, retorno_op: 0.06366013247274194
# Par TAMM4-UBBR11 sem convergência, retorno_op: -0.0027187113872497726
# Par NTCO3-DASA3 sem convergência, retorno_op: 0.07290149535357493
# Par NTCO3-TAMM4 sem convergência, retorno_op: 0.052197321901749305
# Par ELET6-DASA3 sem convergência, retorno_op: -0.014850554936111093
# Par ACES4-EMAE4 sem convergência, retorno_op: 0.13305980126069672
# Par GETI4-DASA3 sem convergência, retorno_op: 0.029930040206208597
# Par CCRO3-TIMS3 sem convergência, retorno_op: 0.0858233262098651
# Par NETC4-UBBR11 sem convergência, retorno_op: 0.016179583588463498
# Par VIVT4-TMAR5 sem convergência, retorno_op: 0.020711720152296387
# Par NTCO3-LIPR3 sem convergência, retorno_op: 0.07402758155084732
# Par TELB3-TELB4 sem convergência, retorno_op: -0.05371008065932359
# Par TELB3-USIM3 sem convergência, retorno_op: -0.05695269507603484
# Par USIM5-TELB3 sem convergência, retorno_op: -0.02241009931314819
# Par CGAS5-DURA4 sem convergência, retorno_op: 0.09383101572934804
# Par PMAM4-TELB3 sem convergência, retorno_op: -0.032014505328157306
# Par VIVT4-TNLP4 sem convergência, retorno_op: 0.013718085501078114
# Par GOAU4-GETI4 sem convergência, retorno_op: 0.02981367112972011
# Par CRUZ3-USIM3 sem convergência, retorno_op: 0.09343499787128651
# Par PTIP4-TELB3 sem convergência, retorno_op: -0.020027491474931214
# Par GOAU4-TELB3 sem convergência, retorno_op: -0.020176620324363626
# Par PETR4-CPFE3 sem convergência, retorno_op: 0.0021239816152416324
# Par SUZB5-TELB3 sem convergência, retorno_op: -0.0694967403460498
# Par DASA3-TAMM4 sem convergência, retorno_op: -0.05877327955256506
# Par CGAS5-TELB3 sem convergência, retorno_op: -0.053683446833039605
# Par BBAS3-NETC4 sem convergência, retorno_op: 0.06709021323407138
# -------------------------------------------------
# Starting period 20 | Past days: 2609
# Par NTCO3-AMBV4 sem convergência, retorno_op: 0.03268219754851831
# Par SUBA3-TELB4 sem convergência, retorno_op: 0.3943390193387133
# Par ITUB4-CPFE3 sem convergência, retorno_op: 0.03837403966272235
# Par DASA3-SUBA3 sem convergência, retorno_op: 0.00939408228421934
# Par ITUB4-DASA3 sem convergência, retorno_op: 0.004636313520787638
# Par CPFE3-AMBV4 sem convergência, retorno_op: 0.024131980060392966
# Par PETR4-TELB4 sem convergência, retorno_op: 0.14423456949033442
# Par NTCO3-DURA4 sem convergência, retorno_op: 0.04613631034380994
# Par DASA3-UBBR11 sem convergência, retorno_op: 0.001112536372890549
# Par CPFE3-SUBA3 sem convergência, retorno_op: 0.02396150957254739
# Par BBDC3-CCRO3 sem convergência, retorno_op: 0.10854357836639394
# Par VIVT3-ARCE3 sem convergência, retorno_op: -0.017621308304709427
# Par ACES4-VCPA4 sem convergência, retorno_op: -0.008546891361338904
# Par ARCE3-CGAS5 sem convergência, retorno_op: 0.03713451903173404
# Par TELB3-USIM3 sem convergência, retorno_op: 0.02019170668344339
# Par BBAS3-EGIE3 sem convergência, retorno_op: 0.09488932022864782
# Par CPFE3-CRUZ3 sem convergência, retorno_op: 0.08619029006824475
# Par BBDC4-CCRO3 sem convergência, retorno_op: 0.09112434643010303
# Par TIMS3-BRAP4 sem convergência, retorno_op: 0.0704349137443483
# Par BBAS3-GOAU4 sem convergência, retorno_op: 0.012991523075906342
# Par BRAP4-TELB3 sem convergência, retorno_op: -0.004167086102210504
# Par VIVT3-SUBA3 sem convergência, retorno_op: 0.0657109959890696
# Par SBSP3-ALLL11 sem convergência, retorno_op: 0.09627865796816404
# Par CPFE3-GETI4 sem convergência, retorno_op: 0.05404654904397832
# Par EMAE4-PCAR4 sem convergência, retorno_op: 0
# Par PETR4-GOAU4 sem convergência, retorno_op: -0.0048681907215877285
# Par BRKM5-LIGT3 sem convergência, retorno_op: -0.011097527779833527
# Par EBTP4-LIGT3 sem convergência, retorno_op: 0.039540553079422835
# Par EBTP3-LIGT3 sem convergência, retorno_op: 0.03880914092508192
# Par CGAS5-VIVT4 sem convergência, retorno_op: 0.029544530588375695
# Par ELET3-GETI4 sem convergência, retorno_op: 0.0887376896722607
# Par USIM5-CRUZ3 sem convergência, retorno_op: 0.1723261004569796
# Par ELET6-SUBA3 sem convergência, retorno_op: 0.03709617085453587
# -------------------------------------------------
# Starting period 21 | Past days: 2738
# Par CPFE3-OIBR4 sem convergência, retorno_op: 0.013436641820780082
# Par ENBR3-TMAR5 sem convergência, retorno_op: 0
# Par ENBR3-TNLP4 sem convergência, retorno_op: 0
# Par EMAE4-VIVO4 sem convergência, retorno_op: 0.13043620521561272
# Par GETI4-CRUZ3 sem convergência, retorno_op: 0.0985130415420441
# Par CYRE3-VIVO3 sem convergência, retorno_op: 0.05913429758793409
# Par CPFE3-RSID3 sem convergência, retorno_op: 0.03208013818958144
# Par BBDC4-CMIG4 sem convergência, retorno_op: 0.05820978483380168
# Par AMBV4-DURA4 sem convergência, retorno_op: 0.05816977416499025
# Par TIMS3-UGPA4 sem convergência, retorno_op: 0.13539421373122074
# Par LREN3-SBSP3 sem convergência, retorno_op: 0
# Par GETI4-AMBV4 sem convergência, retorno_op: 0.09469607860808527
# Par ENBR3-PCAR4 sem convergência, retorno_op: -0.005913220262035335
# Par BRTP4-VIVO3 sem convergência, retorno_op: 0.05969452728004887
# Par EMAE4-TCSL4 sem convergência, retorno_op: 0.08913616253591972
# Par CMIG4-VIVO4 sem convergência, retorno_op: 0.04616573553451364
# Par VALE3-BRTP3 sem convergência, retorno_op: 0
# Par TIMS3-LIGT3 sem convergência, retorno_op: 0.1334937000567853
# Par CMIG4-SDIA4 sem convergência, retorno_op: 0.021653149487001255
# Par CYRE3-UBBR11 sem convergência, retorno_op: 0.07761646920964216
# Par ELET6-CPFE3 sem convergência, retorno_op: 0.14118297236669752
# Par CPFE3-BRTP4 sem convergência, retorno_op: -0.013978904456036556
# Par CPFE3-TMAR5 sem convergência, retorno_op: 0.027080640783930132
# Par CESP5-PCAR4 sem convergência, retorno_op: 0.14573734709339603
# Par BRTP4-SUBA3 sem convergência, retorno_op: 0.09252923641989241
# Par ENBR3-SUBA3 sem convergência, retorno_op: -0.028867819860424637
# Par VALE3-CMIG3 sem convergência, retorno_op: 0
# Par CPFE3-TNLP4 sem convergência, retorno_op: 0.0027699906123408446
# Par ELET6-ARCE3 sem convergência, retorno_op: -0.003349496341501723
# Par GGBR4-OIBR4 sem convergência, retorno_op: -0.0015079842780756358
# Par CMIG3-CPSL3 sem convergência, retorno_op: 0
# Par DASA3-PCAR4 sem convergência, retorno_op: 0
# Par ENBR3-TMCP4 sem convergência, retorno_op: -0.02667817828838359
# Par RENT3-LREN3 sem convergência, retorno_op: 0
# Par CMIG4-TCSL4 sem convergência, retorno_op: 0.026386894669304772
# Par CMIG3-LIGT3 sem convergência, retorno_op: 0
# -------------------------------------------------
# Starting period 22 | Past days: 2869
# Par TELB3-TELB4 sem convergência, retorno_op: -0.35624881610525616
# Par SDIA4-CRUZ3 sem convergência, retorno_op: 0.07747762895826948
# Par CESP5-CRUZ3 sem convergência, retorno_op: 0.07290849561812252
# Par BBAS3-LIGT3 sem convergência, retorno_op: 0.10679741050977798
# Par DASA3-GFSA3 sem convergência, retorno_op: 0.09513015743412279
# Par TCSL4-VIVO3 sem convergência, retorno_op: 0.05527913083013103
# Par GETI4-CRUZ3 sem convergência, retorno_op: 0.21340558592059478
# Par BBDC4-LREN3 sem convergência, retorno_op: 0.044177517402657074
# Par GOAU4-CESP5 sem convergência, retorno_op: -0.043829103278758996
# Par SBSP3-NETC4 sem convergência, retorno_op: 0.06752148810359193
# Par CYRE3-TCSL4 sem convergência, retorno_op: 0.07962459588205295
# Par VIVT3-GETI4 sem convergência, retorno_op: 0.02770199233321291
# Par BRTP4-CRUZ3 sem convergência, retorno_op: 0.27356367208625887
# Par EMBR3-DASA3 sem convergência, retorno_op: 0.15684419889978995
# Par ITUB4-VIVT3 sem convergência, retorno_op: 0.10991196522814195
# Par GETI4-NETC4 sem convergência, retorno_op: -0.060477946251006776
# Par BRTP3-CRUZ3 sem convergência, retorno_op: 0.23522094875195654
# Par ENBR3-GETI4 sem convergência, retorno_op: 0.121362485507585
# Par BBAS3-DURA4 sem convergência, retorno_op: 0.02546464808831761
# Par VIVT3-CRUZ3 sem convergência, retorno_op: 0.24709943746248086
# Par USIM5-CRUZ3 sem convergência, retorno_op: 0.1644575197111453
# Par SBSP3-VIVT3 sem convergência, retorno_op: 0.10140389020375817
# Par CSAN3-TELB3 sem convergência, retorno_op: -0.3543220574390007
# Par TOTS3-ALPA4 sem convergência, retorno_op: 0.03612276473130671
# Par ABEV3-EMAE4 sem convergência, retorno_op: 0.013300668554717676
# Par CSAN3-TELB4 sem convergência, retorno_op: -0.7343106024990589
# Par GETI4-CESP5 sem convergência, retorno_op: -0.008291296612791932
# Par GGBR4-CRUZ3 sem convergência, retorno_op: 0.2043137020245709
# Par ITUB4-NETC4 sem convergência, retorno_op: 0.08091708231780381
# Par CESP5-SDIA4 sem convergência, retorno_op: -0.02277010305801408
# Par LREN3-CESP5 sem convergência, retorno_op: 0.021135316520694447
# Par NTCO3-TAMM4 sem convergência, retorno_op: 0.046953289111649754
# Par USIM3-VALE5 sem convergência, retorno_op: 0.0786751743441596
# Par BRAP4-LAME4 sem convergência, retorno_op: 0.0019769800931908055
# Par CMIG4-INEP4 sem convergência, retorno_op: -0.0032954739033592695
# Par USIM5-BRTP3 sem convergência, retorno_op: 0.12568005654950198
# Par RSID3-TNLP4 sem convergência, retorno_op: 0.23214553444463792
# Par RENT3-BBAS3 sem convergência, retorno_op: 0.14757165572588415
# Par CPFE3-CESP5 sem convergência, retorno_op: -0.10257689240475698
# -------------------------------------------------
# Starting period 23 | Past days: 2999
# Par CPFE3-AMBV4 sem convergência, retorno_op: 0
# Par ABEV3-ITSA4 sem convergência, retorno_op: 0.16388617259527682
# Par BBDC3-EGIE3 sem convergência, retorno_op: -0.0073552752801688825
# Par BBAS3-RSID3 sem convergência, retorno_op: 0.09482302018041677
# Par EMBR3-VIVO3 sem convergência, retorno_op: -0.12940884199162683
# Par ABEV3-EMAE4 sem convergência, retorno_op: -0.033574099745755315
# Par ARCZ6-ALLL3 sem convergência, retorno_op: 0.13569045657085654
# Par TOTS3-BRTP4 sem convergência, retorno_op: 0.11772096734194637
# Par BBAS3-POSI3 sem convergência, retorno_op: 0.1212474956972367
# Par BBDC4-ELPL4 sem convergência, retorno_op: 0
# Par TIMS3-NETC4 sem convergência, retorno_op: 0.07254196220653442
# Par BBDC3-AMBV4 sem convergência, retorno_op: 0.04583484186567999
# Par VALE3-BRFS3 sem convergência, retorno_op: 0.09481687598498789
# Par MMXM3-CRUZ3 sem convergência, retorno_op: 0.344347872811805
# Par BRFS3-VALE5 sem convergência, retorno_op: 0.08002883499660296
# Par ITUB4-CYRE3 sem convergência, retorno_op: 0.09022998903398838
# Par CLSC4-CRUZ3 sem convergência, retorno_op: 0.06197567966283035
# Par BBDC3-RSID3 sem convergência, retorno_op: 0.10609972882339846
# Par AMBV4-RSID3 sem convergência, retorno_op: -0.01072467874556593
# Par ELET3-VIVO4 sem convergência, retorno_op: 0.008755613702093434
# -------------------------------------------------
# Starting period 24 | Past days: 3129
# Par BBDC3-LIGT3 sem convergência, retorno_op: 0.1787832575241869
# Par ELET3-TAEE11 sem convergência, retorno_op: 1.3440841728301212
# Par TAEE11-CLSC4 sem convergência, retorno_op: 0.31901676462945183
# Par VALE3-TAEE11 sem convergência, retorno_op: 1.803422067267169
# Par TAEE11-VALE5 sem convergência, retorno_op: 0.3429346405278417
# Par TAEE11-GETI4 sem convergência, retorno_op: 0.3327218544886892
# Par TAEE11-ELPL4 sem convergência, retorno_op: 0.3630276452764315
# Par TAEE11-CGAS5 sem convergência, retorno_op: 0.3272800011897611
# Par TAEE11-SUZB5 sem convergência, retorno_op: 0.3382586196224265
# Par TAEE11-VCPA4 sem convergência, retorno_op: 0.3499127805528228
# ...
# Par YDUQ3-TELB4 sem convergência, retorno_op: 0.05753085381035827
# Par HGTX3-LAND3 sem convergência, retorno_op: -0.18592962699045756
# Par EMBR3-EMAE4 sem convergência, retorno_op: -0.04080072732722817
# Par BRPR3-SMLS3 sem convergência, retorno_op: 0.18740160701881825
# Par SMTO3-GEPA4 sem convergência, retorno_op: -0.0036690615463177423
# Par ITSA4-BRML3 sem convergência, retorno_op: 0.012229869427492268
# Par SBSP3-EMAE4 sem convergência, retorno_op: -0.03793169470294444
# Par NTCO3-LAND3 sem convergência, retorno_op: -0.05751773386713044
# Par ENBR3-EMAE4 sem convergência, retorno_op: -0.006765753545490583
# Par USIM5-POMO4 sem convergência, retorno_op: -0.029789907278749972
# Par GOAU4-OIBR3 sem convergência, retorno_op: -0.056468037958876005
# Par SANB11-ARZZ3 sem convergência, retorno_op: 0.15895863246200204
# Par LAND3-TRPL4 sem convergência, retorno_op: -0.09052975695261556
# Par ENGI11-TAEE11 sem convergência, retorno_op: 0.027776003879881994
# Par GGBR4-KLBN11 sem convergência, retorno_op: -0.04817815904094136
# -------------------------------------------------
# Starting period 47 | Past days: 6129
# Par LREN3-SBSP3 sem convergência, retorno_op: 0.0184339337863082
# Par SBSP3-VBBR3 sem convergência, retorno_op: 0.04778685340121491
# Par BBSE3-SBSP3 sem convergência, retorno_op: 0.06865431275246792
# Par BRPR3-SAPR11 sem convergência, retorno_op: 0.016372458870955953
# Par LREN3-SAPR11 sem convergência, retorno_op: 0.030640757216293668
# Par SBSP3-MULT3 sem convergência, retorno_op: 0.010462172523565627
# Par ARZZ3-SAPR11 sem convergência, retorno_op: 0.07164086411903137
# Par EQTL3-LREN3 sem convergência, retorno_op: -0.003603918436268838
# Par BRAP4-ENBR3 sem convergência, retorno_op: 0.062321581308209195
# Par EMBR3-LIGT3 sem convergência, retorno_op: 0.07597406305427579
# Par MULT3-SAPR11 sem convergência, retorno_op: 0.0013063488308260318
# Par ITSA4-TELB4 sem convergência, retorno_op: 0.057355615114105696
# Par EQTL3-MULT3 sem convergência, retorno_op: -0.0356712017939147
# Par ENBR3-PDGR3 sem convergência, retorno_op: 0.01325229338103373
# -------------------------------------------------
# Starting period 48 | Past days: 6260
# Par CVCB3-BIDI4 sem convergência, retorno_op: 0.022524863905272863
# Par BIDI4-CMIG3 sem convergência, retorno_op: 0.04764755177228319
# Par ECOR3-EZTC3 sem convergência, retorno_op: 0.14846901688994496
# Par BIDI4-SMLS3 sem convergência, retorno_op: 0.017480163982455776
# Par TOTS3-KLBN11 sem convergência, retorno_op: 0.07206057166217006
# Par KLBN11-EMAE4 sem convergência, retorno_op: -0.22224593226136413
# Par TOTS3-BRAP4 sem convergência, retorno_op: 0.07838503350227954
# Par MRVE3-RLOG3 sem convergência, retorno_op: 0.1769098274891796
# Par VBBR3-UNIP6 sem convergência, retorno_op: 0
# Par BPAN4-BIDI4 sem convergência, retorno_op: -0.04432899510158972
# Par BBAS3-IGTA3 sem convergência, retorno_op: 0.003011897281691045
# Par BRKM5-MRVE3 sem convergência, retorno_op: 0.1629832686741528
# Par VALE3-GNDI3 sem convergência, retorno_op: 0.028444360739138475
# Par GOLL4-BIDI4 sem convergência, retorno_op: 0.023899220802065635
# Par TOTS3-GNDI3 sem convergência, retorno_op: 0.08591202416709587
# Par CVCB3-INEP4 sem convergência, retorno_op: 0.40128847270234
# Par BPAN4-LIGT3 sem convergência, retorno_op: 0.10017072865409671
# Par BBSE3-BRPR3 sem convergência, retorno_op: 0.008943904867324548
# Par BRAP4-ALPA4 sem convergência, retorno_op: 0.023344263360066453
# Par TAEE11-GEPA4 sem convergência, retorno_op: 0.0772723608249768
# Par CMIG4-BIDI4 sem convergência, retorno_op: 0.03919706459259986
# Par CCRO3-MRVE3 sem convergência, retorno_op: 0.18450477493637019
# Par BPAN4-LAND3 sem convergência, retorno_op: 0.01692484256384974
# Par BRAP4-BHIA3 sem convergência, retorno_op: 0.012573910230374796
# Par HYPE3-GEPA4 sem convergência, retorno_op: 0.037147520945172374
# Par HAPV3-BRAP4 sem convergência, retorno_op: 0.05179646282840089
# Par VBBR3-BRKM5 sem convergência, retorno_op: 0.10547249697634431
# Par COGN3-BIDI4 sem convergência, retorno_op: -0.013330997871071837
# Par CSNA3-OIBR3 sem convergência, retorno_op: 0.030277960798406944
# Par BBSE3-RLOG3 sem convergência, retorno_op: 0.10235319025003609
# Par CCRO3-UNIP6 sem convergência, retorno_op: 0
# Par BIDI4-OIBR3 sem convergência, retorno_op: -0.024661823113508508
# Par NTCO3-BRAP4 sem convergência, retorno_op: 0.10637933145991951
# Par GOLL4-INEP4 sem convergência, retorno_op: 0.3908666652821342
# Par KLBN11-BHIA3 sem convergência, retorno_op: 0
# Par IGTA3-UNIP6 sem convergência, retorno_op: -0.0993173916535448
# Par INEP4-SMLS3 sem convergência, retorno_op: 0.0833215744636413
# Par BIDI4-INEP4 sem convergência, retorno_op: -0.04928623027788892
# Par JBSS3-UNIP6 sem convergência, retorno_op: 0
# Par BPAC11-OIBR3 sem convergência, retorno_op: 0.29214475164598186
# Par CIEL3-INEP4 sem convergência, retorno_op: 0.3027868897460315
# Par ATMP3-INEP4 sem convergência, retorno_op: -0.696321289621878
# Par EGIE3-CPFE3 sem convergência, retorno_op: 0.004443909383293754
# -------------------------------------------------
# Starting period 49 | Past days: 6389
# Par LREN3-ENBR3 sem convergência, retorno_op: 0.014703171132613768
# Par HYPE3-CGAS5 sem convergência, retorno_op: 0.04920513836762197
# Par ELET3-CSAN3 sem convergência, retorno_op: 0.08973029504525254
# Par TOTS3-KLBN11 sem convergência, retorno_op: 0.01596048416018947
# Par ELET6-CLSC4 sem convergência, retorno_op: 0.08498322459460317
# Par ENGI11-CPFE3 sem convergência, retorno_op: -0.018538797863874024
# Par BBAS3-EZTC3 sem convergência, retorno_op: 0.05352715728177726
# Par CSAN3-ELET6 sem convergência, retorno_op: 0.07600371580537413
# Par GOAU4-USIM3 sem convergência, retorno_op: 0.04735594618332062
# Par VALE3-DXCO3 sem convergência, retorno_op: 0.023211633634764084
# Par ELET6-SLCE3 sem convergência, retorno_op: -0.020975446849832213
# Par ELET3-SLCE3 sem convergência, retorno_op: -0.010494403728559032
# Par IRBR3-LOGG3 sem convergência, retorno_op: 0.23218852767269293
# Par BBAS3-RADL3 sem convergência, retorno_op: 0.13612610740378228
# Par GEPA4-RSID3 sem convergência, retorno_op: 0.34385701520470446
# Par ENEV3-RRRP3 sem convergência, retorno_op: -0.015270440051057044
# Par CYRE3-QUAL3 sem convergência, retorno_op: 0.2089907405665934
# Par EGIE3-SAPR11 sem convergência, retorno_op: 0.011438634706374184
# Par CVCB3-INEP4 sem convergência, retorno_op: 0.2020132154395149
# Par SLCE3-TRPL4 sem convergência, retorno_op: 0.153357444060517
# Par RADL3-BRPR3 sem convergência, retorno_op: 0.12015594186484924
# Par QUAL3-RSID3 sem convergência, retorno_op: 0.3723120608996382
# Par BPAN4-INEP4 sem convergência, retorno_op: -0.023340945971583427
# Par GGBR4-SLCE3 sem convergência, retorno_op: 0.07118914057942316
# Par HAPV3-TELB3 sem convergência, retorno_op: 0.26129669578228887
# Par ENGI11-EGIE3 sem convergência, retorno_op: -0.022388570786951334
# Par INEP4-TELB4 sem convergência, retorno_op: -0.0154719519544535
# Par SLCE3-BEEF3 sem convergência, retorno_op: 0.07751248610233707
# Par SANB11-SLCE3 sem convergência, retorno_op: 0.15721470449750896
# -------------------------------------------------
# Starting period 52 | Past days: 6783
# Par GGBR4-TRPL4 sem convergência, retorno_op: 0.14281079888558645
# Par GOAU4-SAPR11 sem convergência, retorno_op: 0.11592950797173174
# Par SOMA3-PDGR3 sem convergência, retorno_op: 0.07813370012972021
# Par ENGI11-GOAU4 sem convergência, retorno_op: 0.1453484621375476
# Par ECOR3-TELB4 sem convergência, retorno_op: 0.09493455263126394
# Par VBBR3-PDGR3 sem convergência, retorno_op: -0.058176622596298966
# Par CPFE3-SLCE3 sem convergência, retorno_op: 0.035810363170494686
# Par B3SA3-BRML3 sem convergência, retorno_op: -0.03016799467497222
# Par PCAR3-PDGR3 sem convergência, retorno_op: 0.10915999570912116
# Par GGBR4-ENGI11 sem convergência, retorno_op: 0.08925844470774713
# Par QUAL3-LIGT3 sem convergência, retorno_op: 0.2777090934239972
# Par CSNA3-QUAL3 sem convergência, retorno_op: 0.0907395967767648
# Par LREN3-PDGR3 sem convergência, retorno_op: 0.022387084572481175
# Par WEGE3-PDGR3 sem convergência, retorno_op: 0.04763436212479233
# Par OIBR4-PDGR3 sem convergência, retorno_op: 0.23104993501148585
# Par BRFS3-EMAE4 sem convergência, retorno_op: -0.01260659087088456
# Par IRBR3-PDGR3 sem convergência, retorno_op: -0.03080793941646842
# Par BBDC4-RENT3 sem convergência, retorno_op: 0.18089542517017465
# Par GOLL4-TELB3 sem convergência, retorno_op: 0.11561452288884833
# Par ECOR3-EMAE4 sem convergência, retorno_op: -0.015142610653531507
# Par EQTL3-GOAU4 sem convergência, retorno_op: 0.0956312694193393
# Par RADL3-PDGR3 sem convergência, retorno_op: -0.010169579200298706
# Par FLRY3-EZTC3 sem convergência, retorno_op: 0.03879177069798212
# Par KLBN11-BRKM5 sem convergência, retorno_op: 0.05267607884958192
# Par TOTS3-PDGR3 sem convergência, retorno_op: 0.02147987027097331
# Par CPLE6-SLCE3 sem convergência, retorno_op: 0.1048372120984129
# Par RDOR3-PDGR3 sem convergência, retorno_op: -0.06692857596482149
# Par ECOR3-LIGT3 sem convergência, retorno_op: 0.1883065662239347
# Par RENT3-GOAU4 sem convergência, retorno_op: 0.12894751319612263
# Par CSAN3-PDGR3 sem convergência, retorno_op: -0.03749323413128236
# Par EZTC3-PDGR3 sem convergência, retorno_op: 0.0697371960187727
# Par FLRY3-PDGR3 sem convergência, retorno_op: 0.05046698549571582
# Par CYRE3-PDGR3 sem convergência, retorno_op: 0.08444055421736052
# Par DASA3-LIGT3 sem convergência, retorno_op: 0.23241161468448102
# -------------------------------------------------
# Starting period 53 | Past days: 6912
# Par RAIZ4-TELB3 sem convergência, retorno_op: -0.03868928763518542
# Par LIGT3-TELB3 sem convergência, retorno_op: -0.16529478142449583
# Par BPAN4-SYNE3 sem convergência, retorno_op: 0.006654171246230467
# Par JBSS3-TELB4 sem convergência, retorno_op: 0.5428603293642511
# Par BRKM5-YDUQ3 sem convergência, retorno_op: 0.028805690963229047
# Par YDUQ3-DXCO3 sem convergência, retorno_op: -0.1222963310282057
# Par B3SA3-BHIA3 sem convergência, retorno_op: -0.028529504078107504
# Par CPFE3-CGAS5 sem convergência, retorno_op: 0.0003969142498339018
# Par SOMA3-LWSA3 sem convergência, retorno_op: 0.16421959473609649
# Par BBAS3-EMBR3 sem convergência, retorno_op: 0.08019009967625612
# Par BBDC4-BHIA3 sem convergência, retorno_op: 0.026874692169306602
# Par YDUQ3-USIM3 sem convergência, retorno_op: -0.053175564075743864
# Par BBDC3-BHIA3 sem convergência, retorno_op: -0.0033089474772260985
# Par BHIA3-LOGG3 sem convergência, retorno_op: 0.04479423980875197
# Par SOMA3-BHIA3 sem convergência, retorno_op: -0.08173627643037884
# Par GOLL4-LIGT3 sem convergência, retorno_op: 0
# Par B3SA3-LWSA3 sem convergência, retorno_op: 0.11792064883760833
# Par ITUB4-CGAS5 sem convergência, retorno_op: 0.01301570099920113
# Par MRVE3-DASA3 sem convergência, retorno_op: 0.16817276795847258
# Par USIM5-LIGT3 sem convergência, retorno_op: -0.25791281514007713
# Par EMBR3-POMO4 sem convergência, retorno_op: 0
# Par UGPA3-TIMS3 sem convergência, retorno_op: 0.009994424349933695
# Par COGN3-JHSF3 sem convergência, retorno_op: 0.043460159581118596
# Par BPAC11-ENGI11 sem convergência, retorno_op: 0.013861744540138776
# -------------------------------------------------
# Starting period 54 | Past days: 7044
# Par SMTO3-TELB4 sem convergência, retorno_op: 0.030620330600628076
# Par CMIG4-SAPR11 sem convergência, retorno_op: 0.045695252877145265
# Par TOTS3-SANB11 sem convergência, retorno_op: 0.06212026199359677
# Par NTCO3-CMIG3 sem convergência, retorno_op: 0.09083536139034942
# Par IGTI11-TELB3 sem convergência, retorno_op: -0.015656188045458208
# Par BEEF3-GFSA3 sem convergência, retorno_op: -0.15767383368839072
# Par HYPE3-CIEL3 sem convergência, retorno_op: -0.03921956487111178
# Par LREN3-BRKM5 sem convergência, retorno_op: 0.11927983785196039
# Par CIEL3-LAND3 sem convergência, retorno_op: 0
# Par RAIZ4-LWSA3 sem convergência, retorno_op: -0.002608987111700767
# Par CSAN3-USIM5 sem convergência, retorno_op: -0.05222799289838731
# Par AZUL4-EVEN3 sem convergência, retorno_op: -0.0027347648255084955
# Par TELB3-TELB4 sem convergência, retorno_op: -0.001756260927775699
# Par CIEL3-SLCE3 sem convergência, retorno_op: 0
# Par TOTS3-TAEE11 sem convergência, retorno_op: 0.06177024714810031
# Par RAIL3-TELB4 sem convergência, retorno_op: 0.11166789373763253
# Par CRFB3-GFSA3 sem convergência, retorno_op: -0.09587430747576553
# Par PETR4-SMTO3 sem convergência, retorno_op: -0.03494026476475076
# Par CMIG3-SAPR11 sem convergência, retorno_op: 0.029641467578639613
# Par CMIG4-TELB4 sem convergência, retorno_op: 0.11428584786068718
# Par RRRP3-CIEL3 sem convergência, retorno_op: -0.058262823290403
# Par ITSA4-KLBN11 sem convergência, retorno_op: -0.007926408573662336
# Par PETR3-SMTO3 sem convergência, retorno_op: -0.05392678731947198
# Par MULT3-TELB3 sem convergência, retorno_op: -0.0035476403900052134
# Par CCRO3-TELB3 sem convergência, retorno_op: -0.014972581958767162
# Par TAEE11-TELB3 sem convergência, retorno_op: 0
# Par JBSS3-GFSA3 sem convergência, retorno_op: 0
# Par TOTS3-ENGI11 sem convergência, retorno_op: 0.05390037705521422
# Par CMIG3-TELB4 sem convergência, retorno_op: 0.03953437613488742
# Par TOTS3-CPFE3 sem convergência, retorno_op: 0.07301436259003058
# Par USIM5-TELB4 sem convergência, retorno_op: -0.030613431182057838
# Par ABEV3-TELB3 sem convergência, retorno_op: 0.009738850878280303
# Par BBDC3-TELB3 sem convergência, retorno_op: -0.037799247472350306
# -------------------------------------------------

# %% [markdown]
# ## Salvando os resultados

# %%
cols = ['Operação', 'Semestre', 'Abertura', 'Fechamento', 'Dias', 'Retorno total', 'Ticker 1', 'Ticker 2', 'Converged']
df = pd.DataFrame(resumos, columns = cols)
df['Index'] = df['Ticker 1'].astype(str) + '-' + df['Ticker 2'].astype(str) + '-' + df['Operação'].astype(str)
df['Retorno total - exp'] = np.exp(df['Retorno total'])

#Drive
'''
pasta2 = str("/content/drive/MyDrive/Python/TCC-Cloud/Distancia-Cointegração/result_cointegracao/")
print(pasta2)
'''

#PC:
pasta2 = str(pasta + "/Distancia-Cointegração/result_cointegracao/")
print(pasta2)

#os.makedirs(pasta2, exist_ok=True)
df.to_csv(pasta2 + "operations_C100.csv", sep=',', index=False)
# Out:
# /mnt/c/Users/MarceloPolecram/Python/MEU_TCC/Distancia-Cointegração/result_cointegracao/

# %% [markdown]
# # Rascunhos:
